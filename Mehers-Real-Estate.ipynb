# %% [markdown]
# ## Real Estate Price Predictor

# %%
import pandas as pd

# %%
housing = pd.read_csv("melb_data.csv")

# %%
housing.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 2.2+ MB

# %%
housing['Rooms']
# Out:
# 0        2
# 1        2
# 2        3
# 3        3
# 4        4
#         ..
# 13575    4
# 13576    3
# 13577    3
# 13578    4
# 13579    4
# Name: Rooms, Length: 13580, dtype: int64

# %%
housing.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# std        0.691712      0.962634    3990.669241    541.014538    37.273762
# min        0.000000      0.000000       0.000000      0.000000  1196.000000
# 25%        1.000000      1.000000     177.000000     93.000000  1940.000000
# 50%        1.000000      2.000000     440.000000    126.000000  1970.000000
# 75%        2.000000      2.000000     651.000000    174.000000  1999.000000
# max        8.000000     10.000000  433014.000000  44515.000000  2018.000000
#
#           Lattitude    Longtitude  Propertycount
# count  13580.000000  13580.000000   13580.000000
# mean     -37.809203    144.995216    7454.417378
# std        0.079260      0.103916    4378.581772
# min      -38.182550    144.431810     249.000000
# 25%      -37.856822    144.929600    4380.000000
# 50%      -37.802355    145.000100    6555.000000
# 75%      -37.756400    145.058305   10331.000000
# max      -37.408530    145.526350   21650.000000

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Rooms'}>,
#         <Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Distance'}>,
#         <Axes: title={'center': 'Postcode'}>],
#        [<Axes: title={'center': 'Bedroom2'}>,
#         <Axes: title={'center': 'Bathroom'}>,
#         <Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Landsize'}>],
#        [<Axes: title={'center': 'BuildingArea'}>,
#         <Axes: title={'center': 'YearBuilt'}>,
#         <Axes: title={'center': 'Lattitude'}>,
#         <Axes: title={'center': 'Longtitude'}>],
#        [<Axes: title={'center': 'Propertycount'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# ## Train-Test Splitting

# %%
import numpy as np
def split_train_test(data, test_ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    print(shuffled)
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(housing, 0.2)
# Out:
# [1061 6482 8395 ... 5390  860 7270]

# %%
print(f"Rows in train set: {(len(train_set))}\nRows in test set: {(len(test_set))}\n")
# Out:
# Rows in train set: 10864
# Rows in test set: 2716

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split = train_test_split(housing, test_size=0.2, random_state=42)
print(f"Rows in train set: {(len(train_set))}\nRows in test set: {(len(test_set))}\n")
# Out:
# Rows in train set: 10864
# Rows in test set: 2716

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
housing["Landsize_cat"] = pd.qcut(housing["Landsize"], q=5, labels=False)
for train_index, test_index in split.split(housing, housing['Landsize_cat']):
    start_train_set = housing.loc[train_index]
    start_test_set = housing.loc[test_index]

# %%
start_test_set['Landsize_cat'].value_counts()
# Out:
# Landsize_cat
# 2    547
# 0    544
# 4    543
# 1    542
# 3    540
# Name: count, dtype: int64

# %%
start_train_set['Landsize_cat'].value_counts()
# Out:
# Landsize_cat
# 2    2185
# 0    2178
# 4    2170
# 1    2170
# 3    2161
# Name: count, dtype: int64

# %% [markdown]
# ## Looking For Correlations

# %%
housing.corr(numeric_only=True)
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# Landsize       0.025678  0.037507  0.025004  0.024558  0.025646  0.037130
# BuildingArea   0.124127  0.090981  0.099481  0.055475  0.122319  0.111933
# YearBuilt     -0.065413 -0.323617  0.246379  0.032863 -0.053319  0.152702
# Lattitude      0.015948 -0.212934 -0.130723 -0.406104  0.015925 -0.070594
# Longtitude     0.100771  0.203656  0.239425  0.445357  0.102238  0.118971
# Propertycount -0.081530 -0.042153 -0.054910  0.062304 -0.081350 -0.052201
# Landsize_cat   0.475052  0.315501  0.375715  0.072384  0.463489  0.217322
#
#                     Car  Landsize  BuildingArea  YearBuilt  Lattitude  \
# Rooms          0.408483  0.025678      0.124127  -0.065413   0.015948
# Price          0.238979  0.037507      0.090981  -0.323617  -0.212934
# Distance       0.262994  0.025004      0.099481   0.246379  -0.130723
# Postcode       0.050289  0.024558      0.055475   0.032863  -0.406104
# Bedroom2       0.405325  0.025646      0.122319  -0.053319   0.015925
# Bathroom       0.322246  0.037130      0.111933   0.152702  -0.070594
# Car            1.000000  0.026770      0.096101   0.104515  -0.001963
# Landsize       0.026770  1.000000      0.500485   0.036451   0.009695
# BuildingArea   0.096101  0.500485      1.000000   0.019665   0.043420
# YearBuilt      0.104515  0.036451      0.019665   1.000000   0.060445
# Lattitude     -0.001963  0.009695      0.043420   0.060445   1.000000
# Longtitude     0.063395  0.010833     -0.023810  -0.003470  -0.357634
# Propertycount -0.024295 -0.006854     -0.028840   0.006361   0.047086
# Landsize_cat   0.381917  0.117627      0.082002  -0.085048   0.022690
#
#                Longtitude  Propertycount  Landsize_cat
# Rooms            0.100771      -0.081530      0.475052
# Price            0.203656      -0.042153      0.315501
# Distance         0.239425      -0.054910      0.375715
# Postcode         0.445357       0.062304      0.072384
# Bedroom2         0.102238      -0.081350      0.463489
# Bathroom         0.118971      -0.052201      0.217322
# Car              0.063395      -0.024295      0.381917
# Landsize         0.010833      -0.006854      0.117627
# BuildingArea    -0.023810      -0.028840      0.082002
# YearBuilt       -0.003470       0.006361     -0.085048
# Lattitude       -0.357634       0.047086      0.022690
# Longtitude       1.000000       0.065988      0.153684
# Propertycount    0.065988       1.000000     -0.065069
# Landsize_cat     0.153684      -0.065069      1.000000

# %%
corr_matrix = housing.corr(numeric_only=True)

# %%
corr_matrix['Price'].sort_values(ascending=False)
# Out:
# Price            1.000000
# Rooms            0.496634
# Bedroom2         0.475951
# Bathroom         0.467038
# Landsize_cat     0.315501
# Car              0.238979
# Longtitude       0.203656
# Postcode         0.107867
# BuildingArea     0.090981
# Landsize         0.037507
# Propertycount   -0.042153
# Distance        -0.162522
# Lattitude       -0.212934
# YearBuilt       -0.323617
# Name: Price, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["Price", "Bathroom", "Longtitude", "YearBuilt"]
scatter_matrix(housing[attributes], figsize = (12,8))
# Out:
# array([[<Axes: xlabel='Price', ylabel='Price'>,
#         <Axes: xlabel='Bathroom', ylabel='Price'>,
#         <Axes: xlabel='Longtitude', ylabel='Price'>,
#         <Axes: xlabel='YearBuilt', ylabel='Price'>],
#        [<Axes: xlabel='Price', ylabel='Bathroom'>,
#         <Axes: xlabel='Bathroom', ylabel='Bathroom'>,
#         <Axes: xlabel='Longtitude', ylabel='Bathroom'>,
#         <Axes: xlabel='YearBuilt', ylabel='Bathroom'>],
#        [<Axes: xlabel='Price', ylabel='Longtitude'>,
#         <Axes: xlabel='Bathroom', ylabel='Longtitude'>,
#         <Axes: xlabel='Longtitude', ylabel='Longtitude'>,
#         <Axes: xlabel='YearBuilt', ylabel='Longtitude'>],
#        [<Axes: xlabel='Price', ylabel='YearBuilt'>,
#         <Axes: xlabel='Bathroom', ylabel='YearBuilt'>,
#         <Axes: xlabel='Longtitude', ylabel='YearBuilt'>,
#         <Axes: xlabel='YearBuilt', ylabel='YearBuilt'>]], dtype=object)

# %%
housing.plot(kind="scatter",x="Price", y="YearBuilt", alpha=0.8)
# Out:
# <Axes: xlabel='Price', ylabel='YearBuilt'>

# %% [markdown]
# ## Attribute Combinations

# %%
housing["Tax"] = housing["Price"]/housing["BuildingArea"]

# %%
housing.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5    3067.0  ...     202.0           NaN        NaN
# 1  4/02/2016       2.5    3067.0  ...     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...     134.0         150.0     1900.0
# 3  4/03/2017       2.5    3067.0  ...      94.0           NaN        NaN
# 4  4/06/2016       2.5    3067.0  ...     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# 0        Yarra   -37.7996    144.9984  Northern Metropolitan         4019.0
# 1        Yarra   -37.8079    144.9934  Northern Metropolitan         4019.0
# 2        Yarra   -37.8093    144.9944  Northern Metropolitan         4019.0
# 3        Yarra   -37.7969    144.9969  Northern Metropolitan         4019.0
# 4        Yarra   -37.8072    144.9941  Northern Metropolitan         4019.0
#
#    Landsize_cat           Tax
# 0             1           NaN
# 1             1  13101.265823
# 2             0   9766.666667
# 3             0           NaN
# 4             0  11267.605634
#
# [5 rows x 23 columns]

# %%
corr_matrix = housing.corr(numeric_only=True)
corr_matrix['Price'].sort_values(ascending=False)
# Out:
# Price            1.000000
# Rooms            0.496634
# Bedroom2         0.475951
# Bathroom         0.467038
# Landsize_cat     0.315501
# Car              0.238979
# Longtitude       0.203656
# Postcode         0.107867
# BuildingArea     0.090981
# Tax              0.062249
# Landsize         0.037507
# Propertycount   -0.042153
# Distance        -0.162522
# Lattitude       -0.212934
# YearBuilt       -0.323617
# Name: Price, dtype: float64

# %%
housing.plot(kind="scatter",x="Price", y="Tax", alpha=0.8)
# Out:
# <Axes: xlabel='Price', ylabel='Tax'>

# %%
print(start_train_set.columns)
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount', 'Landsize_cat'],
#       dtype='object')

# %%
housing = start_test_set.drop("Distance", axis =1)
housing_labels = start_test_set["Distance"].copy()

# %% [markdown]
# ## Missing Attributes

# %%
#To take care of Missing attributes , we have three ioptions:
 #1.Get rid of the missing data points
 #2.Get rid of the whole attribute
 #3.Set the value to some value 0 mean or median

# %%
housing.dropna(subset=["Car"]) #Option 1
housing.shape
# Out:
# (2716, 21)

# %%
housing.drop("Car", axis=1) #option 2
# Out:
#                 Suburb            Address  Rooms Type      Price Method  \
# 6295         Thornbury        33 Wales St      3    h  1245000.0      S
# 5525   South Melbourne   806/50 Albert Rd      2    u   593000.0      S
# 573             Balwyn        8 Raynes St      5    h  4000000.0     VB
# 2376          Essendon    1/155 Deakin St      3    h   897000.0      S
# 11888        Bayswater   592 Mountain Hwy      3    h   606000.0      S
# ...                ...                ...    ...  ...        ...    ...
# 4684       Pascoe Vale     63 Cornwall Rd      3    h   721000.0      S
# 4636       Pascoe Vale  1/5 Farringdon St      3    t   790000.0      S
# 13095     Altona North       105 Third Av      4    h   970000.0      S
# 911     Bentleigh East   1/26 Patricia St      3    u   810000.0      S
# 12522    Hawthorn East      2 Homebush Cr      3    h  2710000.0      S
#
#              SellerG        Date  Postcode  Bedroom2  Bathroom  Landsize  \
# 6295   hockingstuart  18/03/2017    3071.0       3.0       1.0     409.0
# 5525          Dingle   3/09/2016    3205.0       2.0       2.0       0.0
# 573               RT  27/11/2016    3103.0       5.0       4.0    1437.0
# 2376           Frank  11/02/2017    3040.0       3.0       1.0     226.0
# 11888        McGrath  29/07/2017    3153.0       3.0       1.0     424.0
# ...              ...         ...       ...       ...       ...       ...
# 4684      Alexkarbon  27/11/2016    3044.0       3.0       1.0     542.0
# 4636            Brad  12/11/2016    3044.0       3.0       3.0     291.0
# 13095        Sweeney  23/09/2017    3025.0       4.0       1.0     561.0
# 911         Woodards  22/05/2016    3165.0       3.0       2.0     316.0
# 12522            Kay   9/09/2017    3123.0       3.0       1.0     615.0
#
#        BuildingArea  YearBuilt    CouncilArea  Lattitude  Longtitude  \
# 6295            NaN        NaN        Darebin  -37.76330   145.00870
# 5525           83.0     2012.0   Port Phillip  -37.83410   144.97130
# 573             NaN        NaN     Boroondara  -37.80580   145.08820
# 2376            NaN     2000.0  Moonee Valley  -37.73930   144.89310
# 11888          94.0     1970.0           Knox  -37.84291   145.25545
# ...             ...        ...            ...        ...         ...
# 4684            NaN        NaN       Moreland  -37.71890   144.93670
# 4636          175.0     2009.0       Moreland  -37.72710   144.92610
# 13095           NaN        NaN            NaN  -37.83224   144.85300
# 911             NaN     1950.0      Glen Eira  -37.92450   145.07730
# 12522           NaN        NaN            NaN  -37.82425   145.05552
#
#                   Regionname  Propertycount  Landsize_cat
# 6295   Northern Metropolitan         8870.0             2
# 5525   Southern Metropolitan         5943.0             0
# 573    Southern Metropolitan         5682.0             4
# 2376    Western Metropolitan         9264.0             1
# 11888   Eastern Metropolitan         5030.0             2
# ...                      ...            ...           ...
# 4684   Northern Metropolitan         7485.0             2
# 4636   Northern Metropolitan         7485.0             1
# 13095   Western Metropolitan         5132.0             3
# 911    Southern Metropolitan        10969.0             2
# 12522  Southern Metropolitan         6482.0             3
#
# [2716 rows x 20 columns]

# %%
median = housing["Car"].median()

# %%
median
# Out:
# np.float64(2.0)

# %%
housing["Car"].fillna(median)
# Out:
# 6295     1.0
# 5525     1.0
# 573      3.0
# 2376     2.0
# 11888    1.0
#         ...
# 4684     2.0
# 4636     1.0
# 13095    5.0
# 911      1.0
# 12522    3.0
# Name: Car, Length: 2716, dtype: float64

# %%
housing.shape
# Out:
# (2716, 21)

# %%
import pandas as pd
housing = housing.select_dtypes(include=['number'])
housing.head()
# Out:
#        Rooms      Price  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 6295       3  1245000.0    3071.0       3.0       1.0  1.0     409.0
# 5525       2   593000.0    3205.0       2.0       2.0  1.0       0.0
# 573        5  4000000.0    3103.0       5.0       4.0  3.0    1437.0
# 2376       3   897000.0    3040.0       3.0       1.0  2.0     226.0
# 11888      3   606000.0    3153.0       3.0       1.0  1.0     424.0
#
#        BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount  \
# 6295            NaN        NaN  -37.76330   145.00870         8870.0
# 5525           83.0     2012.0  -37.83410   144.97130         5943.0
# 573             NaN        NaN  -37.80580   145.08820         5682.0
# 2376            NaN     2000.0  -37.73930   144.89310         9264.0
# 11888          94.0     1970.0  -37.84291   145.25545         5030.0
#
#        Landsize_cat
# 6295              2
# 5525              0
# 573               4
# 2376              1
# 11888             2

# %%
import numpy as np
import pandas as pd

# Replace inf/-inf with NaN (so imputer can handle them)
housing = housing.replace([np.inf, -np.inf], np.nan)

# Drop non-numeric columns dynamically
housing = housing.select_dtypes(include=['number'])

# Now fit the imputer safely
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
housing_imputed = imputer.fit_transform(housing)

# Convert back to DataFrame
housing = pd.DataFrame(housing_imputed, columns=housing.columns)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = "median")
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([ 3.0000000e+00,  9.0500000e+05,  3.0850000e+03,  3.0000000e+00,
#         1.0000000e+00,  2.0000000e+00,  4.3500000e+02,  1.2200000e+02,
#         1.9700000e+03, -3.7802630e+01,  1.4499935e+02,  6.5670000e+03,
#         2.0000000e+00])

# %%
imputer.statistics_.shape
# Out:
# (13,)

# %%
X = imputer.transform(housing)
housing_tr = pd.DataFrame(X, columns=housing.columns)
housing_tr.describe()
# Out:
#              Rooms         Price     Postcode     Bedroom2     Bathroom  \
# count  2716.000000  2.716000e+03  2716.000000  2716.000000  2716.000000
# mean      2.909426  1.072273e+06  3106.409057     2.885125     1.513991
# std       0.957998  6.218582e+05    92.927569     0.956544     0.685678
# min       1.000000  8.500000e+04  3000.000000     0.000000     0.000000
# 25%       2.000000  6.446250e+05  3046.000000     2.000000     1.000000
# 50%       3.000000  9.050000e+05  3085.000000     3.000000     1.000000
# 75%       3.000000  1.330250e+06  3149.000000     3.000000     2.000000
# max       8.000000  5.100000e+06  3977.000000     9.000000     8.000000
#
#                Car      Landsize  BuildingArea    YearBuilt    Lattitude  \
# count  2716.000000   2716.000000   2716.000000  2716.000000  2716.000000
# mean      1.609720    550.606038    151.659516  1967.017305   -37.809982
# std       0.959263   1563.973453    863.723276    27.995620     0.078734
# min       0.000000      0.000000      0.000000  1850.000000   -38.168020
# 25%       1.000000    173.000000    120.000000  1960.000000   -37.856200
# 50%       2.000000    435.000000    122.000000  1970.000000   -37.802630
# 75%       2.000000    654.000000    125.000000  1971.000000   -37.757793
# max       9.000000  44500.000000  44515.000000  2017.000000   -37.453920
#
#         Longtitude  Propertycount  Landsize_cat
# count  2716.000000    2716.000000   2716.000000
# mean    144.995016    7399.427467      1.998527
# std       0.104660    4272.695516      1.414213
# min     144.431810     457.000000      0.000000
# 25%     144.931400    4380.000000      1.000000
# 50%     144.999350    6567.000000      2.000000
# 75%     145.057500   10331.000000      3.000000
# max     145.436980   21650.000000      4.000000

# %% [markdown]
# ## Scikit-learn Design

# %% [markdown]
# Primarily, there are three types of objects
# 1.Estimators- It estimates some parameter based on a dataset.e.g.imputer. It has a fit method and transform method.
#     Fit method- Fits the dataset and calculates internal parameters.
# 2.Transformers- transform method takes input and returns output base on the learnings from fit().
#     It also has a convenience function called fit_transform() which fits and then transforms.
# 3.Predictors- Linear regression model is an example of predictor. fit() and predict() are two common functions.
#     It also gives score() function which will evaluate the predictions.

# %% [markdown]
# ## Creating a Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler 
my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler', StandardScaler()),
])

# %%
housing_num_tr = my_pipeline.fit_transform(housing_tr)

# %%
housing_num_tr
# Out:
# array([[ 9.45628860e-02,  2.77810255e-01, -3.81109482e-01, ...,
#          1.30769157e-01,  3.44242487e-01,  1.04158671e-03],
#        [-9.49472880e-01, -7.70853387e-01,  1.06113932e+00, ...,
#         -2.26645662e-01, -3.40931306e-01, -1.41343316e+00],
#        [ 2.18263442e+00,  4.70889666e+00, -3.66918582e-02, ...,
#          8.90514561e-01, -4.02028115e-01,  1.41551634e+00],
#        ...,
#        [ 1.13859865e+00, -1.64494195e-01, -8.76209816e-01, ...,
#         -1.35718505e+00, -5.30776180e-01,  7.08278962e-01],
#        [ 9.45628860e-02, -4.21834966e-01,  6.30617288e-01, ...,
#          7.86348210e-01,  8.35591921e-01,  1.04158671e-03],
#        [ 9.45628860e-02,  2.63408669e+00,  1.78569157e-01, ...,
#          5.78206639e-01, -2.14758202e-01,  7.08278962e-01]],
#       shape=(2716, 13))

# %%
housing_num_tr.shape
# Out:
# (2716, 13)

# %% [markdown]
# ## Selecting a desired model for Real Estate

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#model = LinearRegression()
#model = DecisionTreeRegressor()
model = RandomForestRegressor()
model.fit(housing_num_tr,housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data = housing.iloc[:5]

# %%
some_labels = housing_labels.iloc[:5]

# %%
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([ 6.489,  2.114,  9.652,  7.909, 21.738])

# %%
some_labels
# Out:
# 6295      6.5
# 5525      2.1
# 573       9.7
# 2376      8.0
# 11888    23.2
# Name: Distance, dtype: float64

# %%
list(some_labels)
# Out:
# [6.5, 2.1, 9.7, 8.0, 23.2]

# %% [markdown]
# ## Evaluating the model

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = model.predict(housing_num_tr)
mse = mean_squared_error(housing_labels, housing_predictions)
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(0.3308313060953929)

# %% [markdown]
# ## Using better evaluation technique- Cross Validation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, housing_num_tr, housing_labels, scoring = "neg_mean_squared_error", cv = 10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([1.00260416, 1.02513506, 0.71573333, 1.02553557, 0.60091956,
#        1.22363942, 0.86275465, 0.70093822, 0.65297578, 0.79713537])

# %%
def print_scores(scores):
    print("Scores: ", scores)
    print("Mean: ", scores.mean())
    print("Standard deviation: ", scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores:  [1.00260416 1.02513506 0.71573333 1.02553557 0.60091956 1.22363942
#  0.86275465 0.70093822 0.65297578 0.79713537]
# Mean:  0.8607371124993703
# Standard deviation:  0.19164825140695418

# %% [markdown]
# ## Saving the model

# %%
import joblib
joblib.dump(model, 'Mehers.pkl')
# Out:
# ['Mehers.pkl']

# %% [markdown]
# ## Testing the model on test data

# %%
from sklearn.metrics import mean_squared_error
X_test = start_test_set.drop("Distance", axis=1).select_dtypes(include=['number'])
X_test_prepared = my_pipeline.transform(X_test)
Y_test = start_test_set["Distance"].copy()
X_test_prepared = my_pipeline.transform(X_test)
final_predictions = model.predict(X_test_prepared)
final_mse = mean_squared_error(Y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
print(final_predictions, list(Y_test))
# Out:
# [ 6.489  2.114  9.652 ...  9.999 13.867  6.599] [6.5, 2.1, 9.7, 8.0, 23.2, 1.6, 4.1, 13.5, 12.6, 7.7, 13.8, 11.2, 12.1, 11.2, 8.4, 14.7, 6.9, 14.7, 14.2, 1.8, 14.6, 14.6, 9.2, 3.1, 9.9, 10.1, 8.4, 13.8, 35.2, 14.8, 14.5, 5.1, 7.8, 14.2, 11.2, 11.5, 11.0, 13.8, 13.3, 11.2, 7.9, 13.0, 9.2, 11.2, 7.8, 13.9, 5.9, 8.4, 11.0, 20.6, 6.4, 12.1, 7.0, 5.9, 2.6, 1.2, 4.6, 31.7, 21.1, 21.3, 2.3, 8.4, 3.0, 10.2, 9.2, 8.8, 8.4, 7.5, 7.0, 19.6, 3.3, 7.0, 6.4, 6.2, 13.8, 31.7, 10.1, 2.0, 5.4, 4.6, 14.0, 2.4, 1.8, 12.1, 11.4, 14.2, 12.1, 10.7, 11.2, 20.5, 11.1, 13.9, 7.7, 19.9, 3.4, 18.0, 2.3, 5.3, 2.6, 10.1, 5.9, 7.0, 18.0, 6.2, 14.3, 10.8, 6.4, 8.5, 8.8, 1.2, 8.8, 0.0, 3.8, 5.5, 20.0, 13.8, 11.7, 4.6, 8.2, 3.5, 12.8, 12.4, 19.6, 14.0, 25.0, 8.0, 12.1, 11.4, 5.0, 5.4, 12.0, 13.9, 8.5, 4.6, 4.5, 14.5, 29.8, 4.5, 10.4, 2.5, 4.5, 7.5, 4.6, 7.8, 13.8, 14.8, 3.5, 10.5, 13.8, 5.6, 39.0, 6.5, 13.0, 9.1, 7.9, 2.7, 10.7, 10.9, 13.5, 7.8, 7.5, 13.7, 6.9, 11.7, 3.5, 4.6, 9.5, 7.5, 3.8, 2.6, 12.2, 6.4, 6.3, 5.1, 8.7, 17.2, 23.0, 10.3, 23.0, 8.8, 2.8, 6.9, 10.5, 13.7, 10.7, 3.8, 5.5, 6.1, 7.8, 10.1, 17.6, 6.5, 5.5, 5.2, 7.8, 10.7, 10.5, 10.5, 10.5, 5.3, 11.8, 8.0, 7.4, 3.3, 7.3, 14.3, 4.2, 20.5, 2.6, 6.5, 14.9, 12.6, 11.2, 12.7, 5.2, 8.2, 17.9, 14.3, 6.4, 1.6, 9.0, 6.1, 4.6, 20.8, 4.6, 15.2, 6.4, 13.5, 11.2, 3.0, 7.5, 13.8, 9.7, 11.2, 9.2, 27.0, 3.8, 11.2, 14.0, 7.9, 9.2, 7.8, 7.0, 6.1, 13.3, 6.2, 10.7, 6.3, 5.6, 13.0, 11.1, 9.2, 13.0, 9.0, 8.8, 16.1, 10.4, 31.7, 7.4, 10.3, 17.9, 10.2, 13.9, 9.2, 23.8, 9.1, 6.3, 9.7, 12.6, 6.4, 5.5, 17.2, 4.6, 3.6, 14.7, 14.0, 13.3, 11.8, 5.2, 7.4, 6.4, 8.9, 8.9, 10.5, 3.0, 23.0, 13.9, 5.3, 5.2, 22.7, 3.4, 5.2, 9.2, 15.4, 11.2, 12.6, 14.2, 13.5, 9.2, 3.3, 11.7, 7.9, 17.4, 5.2, 4.1, 13.9, 2.7, 2.4, 0.7, 47.3, 10.5, 27.0, 24.7, 7.0, 7.3, 6.4, 10.4, 3.5, 5.5, 6.3, 17.4, 8.8, 8.7, 8.4, 7.3, 13.8, 20.5, 13.0, 5.1, 5.9, 7.5, 8.0, 3.3, 6.1, 7.5, 5.3, 5.2, 5.2, 11.2, 11.4, 5.9, 14.7, 10.3, 13.8, 6.1, 9.2, 9.7, 5.9, 12.4, 2.6, 11.0, 6.4, 13.8, 5.4, 6.7, 11.8, 7.8, 8.1, 5.5, 7.2, 14.2, 8.4, 7.3, 5.3, 5.9, 4.5, 8.8, 9.9, 6.4, 17.2, 3.3, 17.9, 1.8, 8.0, 13.0, 13.0, 11.7, 7.5, 5.3, 31.7, 7.5, 2.6, 11.8, 10.5, 29.8, 11.2, 5.4, 11.8, 13.8, 31.7, 14.0, 2.6, 6.4, 7.8, 6.3, 17.4, 4.2, 12.6, 12.4, 7.8, 4.6, 6.2, 8.0, 11.2, 8.5, 3.3, 9.2, 11.8, 7.8, 8.0, 13.0, 9.7, 13.0, 6.9, 10.1, 5.1, 6.4, 13.9, 6.3, 5.9, 5.2, 6.4, 5.3, 8.1, 12.8, 15.2, 5.5, 5.5, 4.6, 6.8, 11.5, 15.4, 13.3, 11.2, 10.2, 8.7, 6.4, 11.4, 6.5, 6.6, 7.8, 15.5, 11.2, 14.8, 13.7, 10.9, 11.7, 13.0, 4.1, 13.9, 13.6, 13.9, 14.7, 12.9, 2.3, 4.1, 14.3, 11.2, 10.5, 4.3, 7.2, 10.4, 13.3, 2.5, 13.0, 9.9, 7.8, 13.9, 17.9, 4.3, 3.3, 9.2, 11.2, 5.9, 11.8, 9.7, 3.3, 13.1, 10.2, 10.5, 3.3, 20.0, 2.4, 2.5, 7.8, 3.8, 18.8, 11.2, 5.6, 7.2, 19.9, 12.1, 12.0, 14.0, 3.3, 7.3, 13.8, 31.7, 4.3, 7.8, 11.5, 14.3, 11.4, 6.1, 7.7, 8.2, 34.9, 9.7, 9.7, 2.3, 13.8, 11.8, 29.8, 16.7, 8.4, 16.1, 21.3, 3.2, 13.0, 6.4, 3.4, 13.9, 7.8, 8.7, 7.9, 21.5, 1.6, 2.6, 7.0, 7.5, 12.6, 4.0, 11.2, 12.6, 13.4, 5.9, 5.0, 11.2, 14.7, 13.5, 6.4, 15.4, 3.3, 5.2, 13.6, 2.5, 1.6, 16.3, 10.4, 23.0, 11.7, 13.7, 7.7, 7.8, 18.4, 14.7, 5.2, 8.9, 11.2, 10.4, 2.7, 8.9, 9.2, 11.2, 9.7, 10.4, 1.6, 11.2, 3.8, 5.1, 9.9, 7.9, 2.5, 5.1, 6.1, 3.3, 3.8, 8.4, 14.7, 14.7, 10.4, 35.2, 8.4, 11.4, 13.9, 9.2, 10.5, 31.7, 5.1, 13.4, 12.9, 16.2, 14.7, 18.4, 13.8, 9.7, 7.3, 13.1, 31.7, 8.5, 10.5, 22.7, 13.9, 11.4, 3.8, 7.8, 8.0, 8.5, 5.5, 12.2, 8.9, 9.2, 11.4, 20.0, 5.5, 6.9, 10.6, 8.8, 10.8, 4.5, 9.2, 21.5, 8.8, 9.7, 3.3, 11.8, 10.6, 8.4, 6.7, 6.9, 11.7, 5.1, 15.5, 9.7, 13.9, 12.1, 8.5, 9.9, 9.0, 5.1, 8.8, 19.9, 4.6, 3.3, 7.5, 9.7, 14.2, 4.6, 13.0, 14.3, 5.9, 6.9, 2.8, 6.2, 29.8, 3.1, 11.2, 18.0, 2.6, 5.1, 12.4, 4.6, 13.4, 13.8, 15.5, 17.9, 8.8, 9.7, 5.4, 18.4, 8.9, 2.4, 11.2, 12.1, 10.7, 3.5, 13.9, 22.7, 9.2, 11.7, 8.4, 8.5, 13.1, 12.1, 11.2, 3.4, 15.4, 9.7, 7.7, 7.9, 14.7, 9.7, 6.5, 11.4, 9.2, 8.8, 9.2, 8.4, 11.2, 5.2, 11.2, 8.4, 6.2, 8.0, 7.0, 6.2, 4.3, 4.3, 11.2, 9.7, 10.6, 19.6, 7.8, 13.3, 7.8, 23.0, 10.1, 11.2, 13.7, 2.4, 14.6, 7.5, 4.2, 4.6, 13 ...

# %%
final_rmse
# Out:
# np.float64(0.3308313060953929)

# %%
prepared_data[0]
# Out:
# array([ 0.09456289,  0.27781026, -0.38110948,  0.12011576, -0.74974834,
#        -0.63573023, -0.09055916, -0.03434547,  0.10656111,  0.59302247,
#         0.13076916,  0.34424249,  0.00104159])

# %% [markdown]
# ## Using the Model

# %%
from joblib import dump, load
import numpy as np
model = load('Mehers.pkl')

# %%
features = np.array([[0.09456289,  0.27781026, -0.38110948,  0.12011576, -0.74974834,
       -0.63573023, -0.09055916, -0.03434547,  0.10656111,  0.59302247,
        0.13076916,  0.34424249,  0.00104159]])
model.predict(features)
# Out:
# array([6.489])
